# %% [markdown]
# ### Standard Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
import sys
sys.path.append("../exp2/")
import gpflow
import tensorflow as tf
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/session_manager.py:31: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/session_manager.py:31: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/misc.py:27: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/misc.py:27: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:156: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:156: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/training/tensorflow_optimizer.py:169: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/saver/coders.py:80: The name tf.data.Iterator is deprecated. Please use tf.compat.v1.data.Iterator instead.
# WARNING:tensorflow:From /home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/saver/coders.py:80: The name tf.data.Iterator is deprecated. Please use tf.compat.v1.data.Iterator instead.

# %%
df = pd.read_csv("../data/beijingb_scaled.csv", index_col = 0)
df = df.rename(columns={'ts': 'Time', 'station_id': 'Station'})

# %%
stations = df['Station'].unique()

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
from gpsampling import GPActive
gp = GPActive(
    df = df,
    train_stations = list(stations[:6]),
    pool_stations = list(stations[6:30]),
    test_stations = list(stations[30:]),
    context_days = 30,
    frequency = 30,
    test_days = 100,
    train_days = 100,
    number_to_query = 1
            )
# gp.active_gp()
# Out:
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 705.135297
#   Number of iterations: 241
#   Number of functions evaluations: 271
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 705.135297
#   Number of iterations: 241
#   Number of functions evaluations: 271

# %%
gp.active_gp()
# Out:
# Current Day before update: 30
#
# Current Day after update: 31
# Stations added -  [1026.0]  on day  31
#
# Train DataFrame Shape (193, 9)
#
# Pool DataFrame Shape (706, 11)
#
# Test DataFrame Shape (4, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 722.674770
#   Number of iterations: 307
#   Number of functions evaluations: 354
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 722.674770
#   Number of iterations: 307
#   Number of functions evaluations: 354
# Current Day before update: 31
#
# Current Day after update: 32
#
# Train DataFrame Shape (200, 9)
#
# Pool DataFrame Shape (727, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 746.564218
#   Number of iterations: 222
#   Number of functions evaluations: 275
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 746.564218
#   Number of iterations: 222
#   Number of functions evaluations: 275
# Current Day before update: 32
#
# Current Day after update: 33
#
# Train DataFrame Shape (207, 9)
#
# Pool DataFrame Shape (749, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 769.710117
#   Number of iterations: 171
#   Number of functions evaluations: 227
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 769.710117
#   Number of iterations: 171
#   Number of functions evaluations: 227
# Current Day before update: 33
#
# Current Day after update: 34
#
# Train DataFrame Shape (214, 9)
#
# Pool DataFrame Shape (771, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 791.977223
#   Number of iterations: 150
#   Number of functions evaluations: 204
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 791.977223
#   Number of iterations: 150
#   Number of functions evaluations: 204
# Current Day before update: 34
#
# Current Day after update: 35
#
# Train DataFrame Shape (221, 9)
#
# Pool DataFrame Shape (793, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 816.084431
#   Number of iterations: 97
#   Number of functions evaluations: 125
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 816.084431
#   Number of iterations: 97
#   Number of functions evaluations: 125
# Current Day before update: 35
#
# Current Day after update: 36
#
# Train DataFrame Shape (228, 9)
#
# Pool DataFrame Shape (816, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 840.494063
#   Number of iterations: 127
#   Number of functions evaluations: 152
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 840.494063
#   Number of iterations: 127
#   Number of functions evaluations: 152
# Current Day before update: 36
#
# Current Day after update: 37
#
# Train DataFrame Shape (235, 9)
#
# Pool DataFrame Shape (839, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 861.945092
#   Number of iterations: 339
#   Number of functions evaluations: 414
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 861.945092
#   Number of iterations: 339
#   Number of functions evaluations: 414
# Current Day before update: 37
#
# Current Day after update: 38
#
# Train DataFrame Shape (242, 9)
#
# Pool DataFrame Shape (862, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 884.233182
#   Number of iterations: 310
#   Number of functions evaluations: 380
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 884.233182
#   Number of iterations: 310
#   Number of functions evaluations: 380
# Current Day before update: 38
#
# Current Day after update: 39
#
# Train DataFrame Shape (249, 9)
#
# Pool DataFrame Shape (885, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 908.750514
#   Number of iterations: 246
#   Number of functions evaluations: 282
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 908.750514
#   Number of iterations: 246
#   Number of functions evaluations: 282
# Current Day before update: 39
#
# Current Day after update: 40
#
# Train DataFrame Shape (256, 9)
#
# Pool DataFrame Shape (908, 11)
#
# Test DataFrame Shape (5, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 929.815378
#   Number of iterations: 537
#   Number of functions evaluations: 635
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 929.815378
#   Number of iterations: 537
#   Number of functions evaluations: 635
# Current Day before update: 40
#
# Current Day after update: 41
#
# Train DataFrame Shape (263, 9)
#
# Pool DataFrame Shape (931, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 956.440819
#   Number of iterations: 352
#   Number of functions evaluations: 437
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 956.440819
#   Number of iterations: 352
#   Number of functions evaluations: 437
# Current Day before update: 41
#
# Current Day after update: 42
#
# Train DataFrame Shape (270, 9)
#
# Pool DataFrame Shape (954, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 987.727752
#   Number of iterations: 102
#   Number of functions evaluations: 125
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 987.727752
#   Number of iterations: 102
#   Number of functions evaluations: 125
# Current Day before update: 42
#
# Current Day after update: 43
#
# Train DataFrame Shape (277, 9)
#
# Pool DataFrame Shape (977, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1014.749697
#   Number of iterations: 188
#   Number of functions evaluations: 219
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1014.749697
#   Number of iterations: 188
#   Number of functions evaluations: 219
# Current Day before update: 43
#
# Current Day after update: 44
#
# Train DataFrame Shape (284, 9)
#
# Pool DataFrame Shape (1000, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1044.609140
#   Number of iterations: 304
#   Number of functions evaluations: 360
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1044.609140
#   Number of iterations: 304
#   Number of functions evaluations: 360
# Current Day before update: 44
#
# Current Day after update: 45
#
# Train DataFrame Shape (291, 9)
#
# Pool DataFrame Shape (1023, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1081.764976
#   Number of iterations: 186
#   Number of functions evaluations: 219
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1081.764976
#   Number of iterations: 186
#   Number of functions evaluations: 219
# Current Day before update: 45
#
# Current Day after update: 46
#
# Train DataFrame Shape (298, 9)
#
# Pool DataFrame Shape (1045, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1113.269832
#   Number of iterations: 258
#   Number of functions evaluations: 288
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1113.269832
#   Number of iterations: 258
#   Number of functions evaluations: 288
# Current Day before update: 46
#
# Current Day after update: 47
#
# Train DataFrame Shape (305, 9)
#
# Pool DataFrame Shape (1067, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1144.441854
#   Number of iterations: 268
#   Number of functions evaluations: 306
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1144.441854
#   Number of iterations: 268
#   Number of functions evaluations: 306
# Current Day before update: 47
#
# Current Day after update: 48
#
# Train DataFrame Shape (312, 9)
#
# Pool DataFrame Shape (1089, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1173.187038
#   Number of iterations: 200
#   Number of functions evaluations: 241
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1173.187038
#   Number of iterations: 200
#   Number of functions evaluations: 241
# Current Day before update: 48
#
# Current Day after update: 49
#
# Train DataFrame Shape (319, 9)
#
# Pool DataFrame Shape (1111, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1197.873573
#   Number of iterations: 131
#   Number of functions evaluations: 151
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1197.873573
#   Number of iterations: 131
#   Number of functions evaluations: 151
# Current Day before update: 49
#
# Current Day after update: 50
#
# Train DataFrame Shape (326, 9)
#
# Pool DataFrame Shape (1133, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1218.157361
#   Number of iterations: 128
#   Number of functions evaluations: 178
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1218.157361
#   Number of iterations: 128
#   Number of functions evaluations: 178
# Current Day before update: 50
#
# Current Day after update: 51
#
# Train DataFrame Shape (333, 9)
#
# Pool DataFrame Shape (1155, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1251.265894
#   Number of iterations: 382
#   Number of functions evaluations: 439
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1251.265894
#   Number of iterations: 382
#   Number of functions evaluations: 439
# Current Day before update: 51
#
# Current Day after update: 52
#
# Train DataFrame Shape (340, 9)
#
# Pool DataFrame Shape (1177, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1273.799658
#   Number of iterations: 122
#   Number of functions evaluations: 198
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1273.799658
#   Number of iterations: 122
#   Number of functions evaluations: 198
# Current Day before update: 52
#
# Current Day after update: 53
#
# Train DataFrame Shape (347, 9)
#
# Pool DataFrame Shape (1198, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1298.447249
#   Number of iterations: 96
#   Number of functions evaluations: 161
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1298.447249
#   Number of iterations: 96
#   Number of functions evaluations: 161
# Current Day before update: 53
#
# Current Day after update: 54
#
# Train DataFrame Shape (354, 9)
#
# Pool DataFrame Shape (1220, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1322.515759
#   Number of iterations: 118
#   Number of functions evaluations: 136
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1322.515759
#   Number of iterations: 118
#   Number of functions evaluations: 136
# Current Day before update: 54
#
# Current Day after update: 55
#
# Train DataFrame Shape (361, 9)
#
# Pool DataFrame Shape (1242, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1357.114685
#   Number of iterations: 257
#   Number of functions evaluations: 314
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1357.114685
#   Number of iterations: 257
#   Number of functions evaluations: 314
# Current Day before update: 55
#
# Current Day after update: 56
#
# Train DataFrame Shape (368, 9)
#
# Pool DataFrame Shape (1264, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1379.933084
#   Number of iterations: 351
#   Number of functions evaluations: 405
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1379.933084
#   Number of iterations: 351
#   Number of functions evaluations: 405
# Current Day before update: 56
#
# Current Day after update: 57
#
# Train DataFrame Shape (375, 9)
#
# Pool DataFrame Shape (1286, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1405.069712
#   Number of iterations: 316
#   Number of functions evaluations: 372
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1405.069712
#   Number of iterations: 316
#   Number of functions evaluations: 372
# Current Day before update: 57
#
# Current Day after update: 58
#
# Train DataFrame Shape (382, 9)
#
# Pool DataFrame Shape (1308, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1427.608472
#   Number of iterations: 225
#   Number of functions evaluations: 267
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1427.608472
#   Number of iterations: 225
#   Number of functions evaluations: 267
# Current Day before update: 58
#
# Current Day after update: 59
#
# Train DataFrame Shape (389, 9)
#
# Pool DataFrame Shape (1330, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1451.733069
#   Number of iterations: 334
#   Number of functions evaluations: 378
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1451.733069
#   Number of iterations: 334
#   Number of functions evaluations: 378
# Current Day before update: 59
#
# Current Day after update: 60
#
# Train DataFrame Shape (395, 9)
#
# Pool DataFrame Shape (1351, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1484.285833
#   Number of iterations: 428
#   Number of functions evaluations: 494
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1484.285833
#   Number of iterations: 428
#   Number of functions evaluations: 494
# Current Day before update: 60
#
# Current Day after update: 61
# Stations added -  [1035.0]  on day  61
#
# Train DataFrame Shape (402, 9)
#
# Pool DataFrame Shape (1328, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1531.395509
#   Number of iterations: 186
#   Number of functions evaluations: 230
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1531.395509
#   Number of iterations: 186
#   Number of functions evaluations: 230
# Current Day before update: 61
#
# Current Day after update: 62
#
# Train DataFrame Shape (409, 9)
#
# Pool DataFrame Shape (1350, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1571.929167
#   Number of iterations: 115
#   Number of functions evaluations: 159
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1571.929167
#   Number of iterations: 115
#   Number of functions evaluations: 159
# Current Day before update: 62
#
# Current Day after update: 63
#
# Train DataFrame Shape (416, 9)
#
# Pool DataFrame Shape (1372, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1606.935090
#   Number of iterations: 315
#   Number of functions evaluations: 350
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1606.935090
#   Number of iterations: 315
#   Number of functions evaluations: 350
# Current Day before update: 63
#
# Current Day after update: 64
#
# Train DataFrame Shape (423, 9)
#
# Pool DataFrame Shape (1394, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1642.546543
#   Number of iterations: 294
#   Number of functions evaluations: 405
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1642.546543
#   Number of iterations: 294
#   Number of functions evaluations: 405
# Current Day before update: 64
#
# Current Day after update: 65
#
# Train DataFrame Shape (430, 9)
#
# Pool DataFrame Shape (1416, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1670.697060
#   Number of iterations: 187
#   Number of functions evaluations: 212
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1670.697060
#   Number of iterations: 187
#   Number of functions evaluations: 212
# Current Day before update: 65
#
# Current Day after update: 66
#
# Train DataFrame Shape (438, 9)
#
# Pool DataFrame Shape (1438, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1708.871379
#   Number of iterations: 192
#   Number of functions evaluations: 219
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1708.871379
#   Number of iterations: 192
#   Number of functions evaluations: 219
# Current Day before update: 66
#
# Current Day after update: 67
#
# Train DataFrame Shape (446, 9)
#
# Pool DataFrame Shape (1460, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1738.977953
#   Number of iterations: 325
#   Number of functions evaluations: 363
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1738.977953
#   Number of iterations: 325
#   Number of functions evaluations: 363
# Current Day before update: 67
#
# Current Day after update: 68
#
# Train DataFrame Shape (454, 9)
#
# Pool DataFrame Shape (1482, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1770.244975
#   Number of iterations: 261
#   Number of functions evaluations: 296
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1770.244975
#   Number of iterations: 261
#   Number of functions evaluations: 296
# Current Day before update: 68
#
# Current Day after update: 69
#
# Train DataFrame Shape (462, 9)
#
# Pool DataFrame Shape (1504, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1801.285483
#   Number of iterations: 199
#   Number of functions evaluations: 229
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1801.285483
#   Number of iterations: 199
#   Number of functions evaluations: 229
# Current Day before update: 69
#
# Current Day after update: 70
#
# Train DataFrame Shape (470, 9)
#
# Pool DataFrame Shape (1526, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1831.690132
#   Number of iterations: 245
#   Number of functions evaluations: 275
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1831.690132
#   Number of iterations: 245
#   Number of functions evaluations: 275
# Current Day before update: 70
#
# Current Day after update: 71
#
# Train DataFrame Shape (478, 9)
#
# Pool DataFrame Shape (1548, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1862.483629
#   Number of iterations: 209
#   Number of functions evaluations: 236
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1862.483629
#   Number of iterations: 209
#   Number of functions evaluations: 236
# Current Day before update: 71
#
# Current Day after update: 72
#
# Train DataFrame Shape (486, 9)
#
# Pool DataFrame Shape (1570, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1894.795745
#   Number of iterations: 272
#   Number of functions evaluations: 307
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1894.795745
#   Number of iterations: 272
#   Number of functions evaluations: 307
# Current Day before update: 72
#
# Current Day after update: 73
#
# Train DataFrame Shape (494, 9)
#
# Pool DataFrame Shape (1591, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#   Objective function value: 1925.811128
#   Number of iterations: 453
#   Number of functions evaluations: 562
# INFO:tensorflow:Optimization terminated with:
#   Message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#   Objective function value: 1925.811128
#   Number of iterations: 453
#   Number of functions evaluations: 562
# Current Day before update: 73
#
# Current Day after update: 74
#
# Train DataFrame Shape (502, 9)
#
# Pool DataFrame Shape (1611, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1960.148946
#   Number of iterations: 321
#   Number of functions evaluations: 365
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 1960.148946
#   Number of iterations: 321
#   Number of functions evaluations: 365
# Current Day before update: 74
#
# Current Day after update: 75
#
# Train DataFrame Shape (510, 9)
#
# Pool DataFrame Shape (1633, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2001.149799
#   Number of iterations: 464
#   Number of functions evaluations: 511
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2001.149799
#   Number of iterations: 464
#   Number of functions evaluations: 511
# Current Day before update: 75
#
# Current Day after update: 76
#
# Train DataFrame Shape (518, 9)
#
# Pool DataFrame Shape (1655, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2045.073238
#   Number of iterations: 311
#   Number of functions evaluations: 380
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2045.073238
#   Number of iterations: 311
#   Number of functions evaluations: 380
# Current Day before update: 76
#
# Current Day after update: 77
#
# Train DataFrame Shape (526, 9)
#
# Pool DataFrame Shape (1677, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2079.395763
#   Number of iterations: 140
#   Number of functions evaluations: 179
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2079.395763
#   Number of iterations: 140
#   Number of functions evaluations: 179
# Current Day before update: 77
#
# Current Day after update: 78
#
# Train DataFrame Shape (534, 9)
#
# Pool DataFrame Shape (1699, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2112.610810
#   Number of iterations: 180
#   Number of functions evaluations: 218
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2112.610810
#   Number of iterations: 180
#   Number of functions evaluations: 218
# Current Day before update: 78
#
# Current Day after update: 79
#
# Train DataFrame Shape (542, 9)
#
# Pool DataFrame Shape (1720, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2143.221032
#   Number of iterations: 181
#   Number of functions evaluations: 249
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2143.221032
#   Number of iterations: 181
#   Number of functions evaluations: 249
# Current Day before update: 79
#
# Current Day after update: 80
#
# Train DataFrame Shape (550, 9)
#
# Pool DataFrame Shape (1741, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2174.437411
#   Number of iterations: 208
#   Number of functions evaluations: 252
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2174.437411
#   Number of iterations: 208
#   Number of functions evaluations: 252
# Current Day before update: 80
#
# Current Day after update: 81
#
# Train DataFrame Shape (558, 9)
#
# Pool DataFrame Shape (1762, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2206.228077
#   Number of iterations: 188
#   Number of functions evaluations: 214
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2206.228077
#   Number of iterations: 188
#   Number of functions evaluations: 214
# Current Day before update: 81
#
# Current Day after update: 82
#
# Train DataFrame Shape (566, 9)
#
# Pool DataFrame Shape (1784, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2247.945541
#   Number of iterations: 122
#   Number of functions evaluations: 187
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2247.945541
#   Number of iterations: 122
#   Number of functions evaluations: 187
# Current Day before update: 82
#
# Current Day after update: 83
#
# Train DataFrame Shape (574, 9)
#
# Pool DataFrame Shape (1804, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2230.420950
#   Number of iterations: 340
#   Number of functions evaluations: 384
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2230.420950
#   Number of iterations: 340
#   Number of functions evaluations: 384
# Current Day before update: 83
#
# Current Day after update: 84
#
# Train DataFrame Shape (582, 9)
#
# Pool DataFrame Shape (1824, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2256.803546
#   Number of iterations: 574
#   Number of functions evaluations: 688
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2256.803546
#   Number of iterations: 574
#   Number of functions evaluations: 688
# Current Day before update: 84
#
# Current Day after update: 85
#
# Train DataFrame Shape (590, 9)
#
# Pool DataFrame Shape (1844, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2285.436353
#   Number of iterations: 593
#   Number of functions evaluations: 724
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2285.436353
#   Number of iterations: 593
#   Number of functions evaluations: 724
# Current Day before update: 85
#
# Current Day after update: 86
#
# Train DataFrame Shape (598, 9)
#
# Pool DataFrame Shape (1866, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2320.638248
#   Number of iterations: 367
#   Number of functions evaluations: 424
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2320.638248
#   Number of iterations: 367
#   Number of functions evaluations: 424
# Current Day before update: 86
#
# Current Day after update: 87
#
# Train DataFrame Shape (606, 9)
#
# Pool DataFrame Shape (1888, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2386.763711
#   Number of iterations: 287
#   Number of functions evaluations: 350
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2386.763711
#   Number of iterations: 287
#   Number of functions evaluations: 350
# Current Day before update: 87
#
# Current Day after update: 88
#
# Train DataFrame Shape (614, 9)
#
# Pool DataFrame Shape (1910, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2496.557680
#   Number of iterations: 285
#   Number of functions evaluations: 347
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2496.557680
#   Number of iterations: 285
#   Number of functions evaluations: 347
# Current Day before update: 88
#
# Current Day after update: 89
# Current Day before update: 89
#
# Current Day after update: 90
# Current Day before update: 90
#
# Current Day after update: 91
# Stations added -  [1036.0]  on day  91
# Current Day before update: 91
#
# Current Day after update: 92
# Current Day before update: 92
#
# Current Day after update: 93
# Current Day before update: 93
#
# Current Day after update: 94
# Current Day before update: 94
#
# Current Day after update: 95
# Current Day before update: 95
#
# Current Day after update: 96
#
# Train DataFrame Shape (622, 9)
#
# Pool DataFrame Shape (1907, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2528.284196
#   Number of iterations: 343
#   Number of functions evaluations: 399
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2528.284196
#   Number of iterations: 343
#   Number of functions evaluations: 399
# Current Day before update: 96
#
# Current Day after update: 97
#
# Train DataFrame Shape (630, 9)
#
# Pool DataFrame Shape (1928, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2559.821437
#   Number of iterations: 286
#   Number of functions evaluations: 327
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2559.821437
#   Number of iterations: 286
#   Number of functions evaluations: 327
# Current Day before update: 97
#
# Current Day after update: 98
#
# Train DataFrame Shape (638, 9)
#
# Pool DataFrame Shape (1949, 11)
#
# Test DataFrame Shape (6, 9)
# CHOLESKY FAILED
# Current Day before update: 98
#
# Current Day after update: 99
#
# Train DataFrame Shape (646, 9)
#
# Pool DataFrame Shape (1970, 11)
#
# Test DataFrame Shape (6, 9)
# CHOLESKY FAILED
# Current Day before update: 99
#
# Current Day after update: 100
#
# Train DataFrame Shape (648, 9)
#
# Pool DataFrame Shape (1991, 11)
#
# Test DataFrame Shape (6, 9)
# CHOLESKY FAILED
# Current Day before update: 100
#
# Current Day after update: 101
#
# Train DataFrame Shape (651, 9)
#
# Pool DataFrame Shape (2011, 11)
#
# Test DataFrame Shape (6, 9)
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2637.178309
#   Number of iterations: 266
#   Number of functions evaluations: 340
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 2637.178309
#   Number of iterations: 266
#   Number of functions evaluations: 340
# Current Day before update: 101
#
# Current Day after update: 102
#
# Train DataFrame Shape (654, 9)
#
# Pool DataFrame Shape (2031, 11)
#
# Test DataFrame Shape (6, 9)
# CHOLESKY FAILED
# Current Day before update: 102
#
# Current Day after update: 103
#
# Train DataFrame Shape (657, 9)
#
# Pool DataFrame Shape (2052, 11)
#
# Test DataFrame Shape (6, 9)
# CHOLESKY FAILED
# Current Day before update: 103
#
# Current Day after update: 104
#
# Train DataFrame Shape (660, 9)
#
# Pool DataFrame Shape (2073, 11)
#
# Test DataFrame Shape (6, 9)
# Exception ignored in: <function BaseSession.__del__ at 0x7f58fdd5fef0>
# Traceback (most recent call last):
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 752, in __del__
#     self.close()
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 747, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt:
# CHOLESKY FAILED
# Current Day before update: 104
#
# Current Day after update: 105
#
# Train DataFrame Shape (663, 9)
#
# Pool DataFrame Shape (2094, 11)
#
# Test DataFrame Shape (6, 9)
# Exception ignored in: <function BaseSession.__del__ at 0x7f58fdd5fef0>
# Traceback (most recent call last):
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 752, in __del__
#     self.close()
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py", line 747, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Tensor'>):
# <tf.Tensor 'Matern52-eb7c32b6-5467/lengthscales/IsVariableInitialized:0' shape=() dtype=bool>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 378, in dispatch_queue
#     yield self.process_one()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 225, in wrapper
#     runner = Runner(result, future, yielded)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 714, in __init__
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-12-cf30362a9305>", line 1, in <module>
#     gp.active_gp()  File "../exp2/gpsampling.py", line 361, in active_gp
#     self.gp_train()  File "../exp2/gpsampling.py", line 295, in gp_train
#     print("CHOLESKY FAILED")  File "</home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/decorator.py:decorator-gen-135>", line 2, in __init__  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/compilable.py", line 157, in init_wrapper
#     self.initialize(force=True)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/node.py", line 156, in build
#     self._build()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/params/parameterized.py", line 302, in _build
#     self._prior_tensor = self._build_prior(priors)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/node.py", line 156, in build
#     self._build()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/params/parameter.py", line 373, in _build
#     self._prior_tensor = prior  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/util/tf_should_use.py", line 193, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Tensor'>):
# <tf.Tensor 'Matern52-eb7c32b6-5467/lengthscales/IsVariableInitialized:0' shape=() dtype=bool>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 378, in dispatch_queue
#     yield self.process_one()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 225, in wrapper
#     runner = Runner(result, future, yielded)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 714, in __init__
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
# ...
#     exec(code, run_globals)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 378, in dispatch_queue
#     yield self.process_one()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 225, in wrapper
#     runner = Runner(result, future, yielded)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 714, in __init__
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-12-cf30362a9305>", line 1, in <module>
#     gp.active_gp()  File "../exp2/gpsampling.py", line 361, in active_gp
#     self.gp_train()  File "../exp2/gpsampling.py", line 295, in gp_train
#     print("CHOLESKY FAILED")  File "</home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/decorator.py:decorator-gen-135>", line 2, in __init__  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/compilable.py", line 157, in init_wrapper
#     self.initialize(force=True)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/node.py", line 156, in build
#     self._build()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/params/parameterized.py", line 302, in _build
#     self._prior_tensor = self._build_prior(priors)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/node.py", line 156, in build
#     self._build()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/params/parameter.py", line 373, in _build
#     self._prior_tensor = prior  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/util/tf_should_use.py", line 193, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Tensor'>):
# <tf.Tensor 'SquaredExponential-0f4696c5-5524/variance/IsVariableInitialized:0' shape=() dtype=bool>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 378, in dispatch_queue
#     yield self.process_one()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 225, in wrapper
#     runner = Runner(result, future, yielded)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 714, in __init__
#     self.run()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)  File "<ipython-input-12-cf30362a9305>", line 1, in <module>
#     gp.active_gp()  File "../exp2/gpsampling.py", line 361, in active_gp
#     self.gp_train()  File "../exp2/gpsampling.py", line 295, in gp_train
#     print("CHOLESKY FAILED")  File "</home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/decorator.py:decorator-gen-135>", line 2, in __init__  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/compilable.py", line 157, in init_wrapper
#     self.initialize(force=True)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/node.py", line 156, in build
#     self._build()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/params/parameterized.py", line 302, in _build
#     self._prior_tensor = self._build_prior(priors)  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/core/node.py", line 156, in build
#     self._build()  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/gpflow/params/parameter.py", line 373, in _build
#     self._prior_tensor = prior  File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/tensorflow/python/util/tf_should_use.py", line 193, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
# ==================================
# CHOLESKY FAILED
# Current Day before update: 105
#
# Current Day after update: 106
#
# Train DataFrame Shape (666, 9)
#
# Pool DataFrame Shape (2115, 11)
#
# Test DataFrame Shape (6, 9)
# CHOLESKY FAILED
# Current Day before update: 106
#
# Current Day after update: 107
#
# Train DataFrame Shape (669, 9)
#
# Pool DataFrame Shape (2136, 11)
#
# Test DataFrame Shape (6, 9)
# CHOLESKY FAILED
# Current Day before update: 107
#
# Current Day after update: 108
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-cf30362a9305>", line 1, in <module>
#     gp.active_gp()
#   File "../exp2/gpsampling.py", line 330, in active_gp
#     temp = self.train.groupby('Time').get_group(time)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/pandas/core/generic.py", line 7894, in groupby
#     **kwargs
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/pandas/core/groupby/groupby.py", line 2522, in groupby
#     return klass(obj, by, **kwds)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/pandas/core/groupby/groupby.py", line 391, in __init__
#     mutated=self.mutated,
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/pandas/core/groupby/grouper.py", line 664, in _get_grouper
#     grouper = BaseGrouper(group_axis, groupings, sort=sort, mutated=mutated)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/pandas/core/groupby/ops.py", line 136, in __init__
#     self.groupings = groupings
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/inspect.py", line 1464, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 185, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/linecache.py", line 137, in updatecache
#     lines = fp.readlines()
#   File "/home/deepak/anaconda3/envs/tf_gpu/lib/python3.7/codecs.py", line 319, in decode
#     def decode(self, input, final=False):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
gp.gp_rmse[:59].mean()
# Out:
# 24.00270168685469
