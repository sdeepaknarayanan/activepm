# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
freq_table = {}
for kout in range(6):
    for kin in range(5):
        a = list(np.load(f'../../exp2/src/results/30/final_gp/{kout}_{kin}/final_rmse.npy'))
        plt.plot(a)
        plt.show()
        plt.close()
        ix = a.index(max(a))
        freq_table[ix] = freq_table.get(ix, 0) + 1
        print (ix)
# Out:
# 300
# 300
# 300
# 300
# 300
# 190
# 312
# 173
# 63
# 172
# 172
# 169
# 172
# 208
# 172
# 171
# 258
# 261
# 59
# 300
# 261
# 312
# 261
# 261
# 261
# 172
# 300
# 172
# 167
# 172

# %%
ls '../../exp2/src/results/30/final_gp/0_0'
# Out:
# final_mae.npy  final_rmse.npy  stations.npy
