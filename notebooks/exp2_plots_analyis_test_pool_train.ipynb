# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.style
import matplotlib as mpl
from sklearn.model_selection import KFold


from common_functions import foo
mpl.style.use('classic')

# %load_ext autoreload
# %autoreload 2
results = "results"

# %%
from common_functions import latexify, format_axes, tableau20blind
latexify(14, 8)

# %%
params = {
    'lines.linewidth': 2,
    'lines.color': 'k',
#     'boxplot.boxprops.linewidth': 20,
    'boxplot.boxprops.color': 'k',
    'patch.linewidth': 2,
    'legend.fontsize': 14 + 4,
    'legend.framealpha': .6,
    'axes.titlesize': 14 + 4,
    "axes.labelsize": 14 + 4,
    'xtick.labelsize': 14 + 4,
    'ytick.labelsize': 16 + 4,
#     'axes.labelweight': 'bold',
    'axes.linewidth': 2,
#     'font.weight': 'bold'
    
}
matplotlib.rcParams.update(params)

# %%
datafile = '../data/beijinga_scaled.csv'

# %%
splits = 6
datadf = pd.read_csv(datafile, index_col=0)
allStations = datadf['station_id'].unique()
allStations.sort()

kfout = KFold(n_splits=splits, shuffle=True, random_state=0)
kfin = KFold(n_splits=splits - 1, shuffle=True, random_state=0)
datadf.head()
# Out:
#    latitude  longitude        ts  station_id       PM2.5
# 0   0.58292    0.17557  0.000000      1001.0  156.250000
# 0   0.58292    0.17557  0.002747      1001.0   24.833333
# 0   0.58292    0.17557  0.005495      1001.0   72.583333
# 0   0.58292    0.17557  0.008242      1001.0   30.043478
# 0   0.58292    0.17557  0.010989      1001.0   23.083333

# %%
df = foo(30, 'results', True)
lastKDays = 30

# %%
df.groupby("reg").mean()
# Out:
#             kout       kin         day       rmse  lastKDays      seed
# reg
# gp      2.498016  2.001424  163.983420  20.665598       30.0 -1.000000
# gp_rd   2.499959  1.999573  163.968984  24.380714       30.0  2.000305
# knn     2.500000  2.000000  164.000000  30.679426       30.0 -1.000000
# knn_rd  2.500000  2.000000  164.000000  30.541583       30.0  2.000000
# qbc     2.500000  2.000000  164.000000  22.671395       30.0 -1.000000
# qbc_rd  2.500000  2.000000  164.000000  24.136366       30.0  2.000000

# %%
for ix, tempdf in df.groupby(["kout", "kin"]):
    
    print ("kout, kin :", *ix)
    tempdf2 = tempdf.groupby("reg").mean()
    print (tempdf2)#.loc["gp"]-tempdf2.loc["qbc"])
# Out:
# kout, kin : 0 0
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       0.0  0.0  164.000000  17.802756       30.0  -1.0
# gp_rd    0.0  0.0  163.864717  15.528422       30.0   2.0
# knn      0.0  0.0  164.000000  29.288422       30.0  -1.0
# knn_rd   0.0  0.0  164.000000  29.887908       30.0   2.0
# qbc      0.0  0.0  164.000000  21.406033       30.0  -1.0
# qbc_rd   0.0  0.0  164.000000  22.579522       30.0   2.0
# kout, kin : 0 1
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       0.0  1.0  163.779817  18.730737       30.0 -1.000000
# gp_rd    0.0  1.0  163.871184  23.861666       30.0  2.001832
# knn      0.0  1.0  164.000000  29.395858       30.0 -1.000000
# knn_rd   0.0  1.0  164.000000  31.588047       30.0  2.000000
# qbc      0.0  1.0  164.000000  20.735624       30.0 -1.000000
# qbc_rd   0.0  1.0  164.000000  26.489254       30.0  2.000000
# kout, kin : 0 2
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       0.0  2.0  164.000000  16.141234       30.0  -1.0
# gp_rd    0.0  2.0  164.112058  21.832324       30.0   2.0
# knn      0.0  2.0  164.000000  29.423654       30.0  -1.0
# knn_rd   0.0  2.0  164.000000  31.196717       30.0   2.0
# qbc      0.0  2.0  164.000000  20.870854       30.0  -1.0
# qbc_rd   0.0  2.0  164.000000  27.253553       30.0   2.0
# kout, kin : 0 3
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       0.0  3.0  163.730061  16.048475       30.0  -1.0
# gp_rd    0.0  3.0  163.911423  24.060687       30.0   2.0
# knn      0.0  3.0  164.000000  29.044109       30.0  -1.0
# knn_rd   0.0  3.0  164.000000  31.143122       30.0   2.0
# qbc      0.0  3.0  164.000000  21.340754       30.0  -1.0
# qbc_rd   0.0  3.0  164.000000  25.298016       30.0   2.0
# kout, kin : 0 4
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       0.0  4.0  164.000000  17.473157       30.0 -1.000000
# gp_rd    0.0  4.0  163.851401  18.715942       30.0  1.999391
# knn      0.0  4.0  164.000000  30.127056       30.0 -1.000000
# knn_rd   0.0  4.0  164.000000  31.150886       30.0  2.000000
# qbc      0.0  4.0  164.000000  19.845238       30.0 -1.000000
# qbc_rd   0.0  4.0  164.000000  26.072863       30.0  2.000000
# kout, kin : 1 0
#         kout  kin         day       rmse  lastKDays     seed
# reg
# gp       1.0  0.0  164.280488  23.646782       30.0 -1.00000
# gp_rd    1.0  0.0  164.177547  27.334148       30.0  1.99939
# knn      1.0  0.0  164.000000  35.064028       30.0 -1.00000
# knn_rd   1.0  0.0  164.000000  33.498445       30.0  2.00000
# qbc      1.0  0.0  164.000000  21.908128       30.0 -1.00000
# qbc_rd   1.0  0.0  164.000000  25.104937       30.0  2.00000
# kout, kin : 1 1
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       1.0  1.0  164.064024  33.002368       30.0 -1.000000
# gp_rd    1.0  1.0  164.092683  28.656732       30.0  1.998171
# knn      1.0  1.0  164.000000  32.812236       30.0 -1.000000
# knn_rd   1.0  1.0  164.000000  33.146331       30.0  2.000000
# qbc      1.0  1.0  164.000000  26.196880       30.0 -1.000000
# qbc_rd   1.0  1.0  164.000000  26.221670       30.0  2.000000
# kout, kin : 1 2
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       1.0  2.0  163.828746  20.342996       30.0 -1.000000
# gp_rd    1.0  2.0  163.976843  21.063268       30.0  1.999391
# knn      1.0  2.0  164.000000  32.913327       30.0 -1.000000
# knn_rd   1.0  2.0  164.000000  31.554529       30.0  2.000000
# qbc      1.0  2.0  164.000000  22.240882       30.0 -1.000000
# qbc_rd   1.0  2.0  164.000000  24.350030       30.0  2.000000
# kout, kin : 1 3
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       1.0  3.0  164.000000  24.159422       30.0  -1.0
# gp_rd    1.0  3.0  163.946984  33.726151       30.0   2.0
# knn      1.0  3.0  164.000000  33.735099       30.0  -1.0
# knn_rd   1.0  3.0  164.000000  33.535992       30.0   2.0
# qbc      1.0  3.0  164.000000  27.722887       30.0  -1.0
# qbc_rd   1.0  3.0  164.000000  26.852622       30.0   2.0
# kout, kin : 1 4
#         kout  kin         day       rmse  lastKDays     seed
# reg
# gp       1.0  4.0  164.000000  20.990909       30.0 -1.00000
# gp_rd    1.0  4.0  163.968807  25.794818       30.0  2.00367
# knn      1.0  4.0  164.000000  36.237560       30.0 -1.00000
# knn_rd   1.0  4.0  164.000000  36.273619       30.0  2.00000
# qbc      1.0  4.0  164.000000  24.721439       30.0 -1.00000
# qbc_rd   1.0  4.0  164.000000  26.959579       30.0  2.00000
# kout, kin : 2 0
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       2.0  0.0  163.969419  22.561396       30.0 -1.000000
# gp_rd    2.0  0.0  164.218082  25.235056       30.0  2.001833
# knn      2.0  0.0  164.000000  29.204446       30.0 -1.000000
# knn_rd   2.0  0.0  164.000000  31.260653       30.0  2.000000
# qbc      2.0  0.0  164.000000  22.066743       30.0 -1.000000
# qbc_rd   2.0  0.0  164.000000  24.320577       30.0  2.000000
# kout, kin : 2 1
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       2.0  1.0  164.103659  27.353040       30.0 -1.000000
# gp_rd    2.0  1.0  163.687233  33.998432       30.0  1.992059
# knn      2.0  1.0  164.000000  31.367885       30.0 -1.000000
# knn_rd   2.0  1.0  164.000000  30.389108       30.0  2.000000
# qbc      2.0  1.0  164.000000  22.509611       30.0 -1.000000
# qbc_rd   2.0  1.0  164.000000  23.505633       30.0  2.000000
# kout, kin : 2 2
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       2.0  2.0  164.000000  21.697289       30.0 -1.000000
# gp_rd    2.0  2.0  163.968273  25.903191       30.0  1.997559
# knn      2.0  2.0  164.000000  32.757262       30.0 -1.000000
# knn_rd   2.0  2.0  164.000000  32.812159       30.0  2.000000
# qbc      2.0  2.0  164.000000  25.021553       30.0 -1.000000
# qbc_rd   2.0  2.0  164.000000  26.058224       30.0  2.000000
# kout, kin : 2 3
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       2.0  3.0  163.603659  23.186194       30.0 -1.000000
# gp_rd    2.0  3.0  163.947304  29.827743       30.0  1.998775
# knn      2.0  3.0  164.000000  29.538718       30.0 -1.000000
# knn_rd   2.0  3.0  164.000000  32.131045       30.0  2.000000
# qbc      2.0  3.0  164.000000  23.565216       30.0 -1.000000
# qbc_rd   2.0  3.0  164.000000  26.701648       30.0  2.000000
# kout, kin : 2 4
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       2.0  4.0  164.000000  19.074389       30.0 -1.000000
# gp_rd    2.0  4.0  164.020706  26.367620       30.0  2.001218
# knn      2.0  4.0  164.000000  30.978710       30.0 -1.000000
# knn_rd   2.0  4.0  164.000000  35.203243       30.0  2.000000
# qbc      2.0  4.0  164.000000  29.043538       30.0 -1.000000
# qbc_rd   2.0  4.0  164.000000  29.653400       30.0  2.000000
# kout, kin : 3 0
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       3.0  0.0  163.886850  18.545655       30.0 -1.000000
# gp_rd    3.0  0.0  164.005484  22.813671       30.0  2.002438
# knn      3.0  0.0  164.000000  28.815074       30.0 -1.000000
# knn_rd   3.0  0.0  164.000000  28.832594       30.0  2.000000
# qbc      3.0  0.0  164.000000  23.456023       30.0 -1.000000
# qbc_rd   3.0  0.0  164.000000  21.224969       30.0  2.000000
# kout, kin : 3 1
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       3.0  1.0  164.000000  17.899626       30.0  -1.0
# gp_rd    3.0  1.0  163.684982  19.760667       30.0   2.0
# knn      3.0  1.0  164.000000  30.956527       30.0  -1.0
# knn_rd   3.0  1.0  164.000000  28.062848       30.0   2.0
# qbc      3.0  1.0  164.000000  21.091504       30.0  -1.0
# qbc_rd   3.0  1.0  164.000000  20.704159       30.0   2.0
# kout, kin : 3 2
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       3.0  2.0  163.782875  17.015215       30.0 -1.000000
# gp_rd    3.0  2.0  164.148533  22.814534       30.0  2.003056
# knn      3.0  2.0  164.000000  26.256905       30.0 -1.000000
# knn_rd   3.0  2.0  164.000000  25.770102       30.0  2.000000
# qbc      3.0  2.0  164.000000  17.737834       30.0 -1.000000
# qbc_rd   3.0  2.0  164.000000  18.733902       30.0  2.000000
# kout, kin : 3 3
#         kout  kin         day       rmse  lastKDays     seed
# reg
# gp       3.0  3.0  164.474006  14.963119       30.0 -1.00000
# gp_rd    3.0  3.0  163.732154  20.967332       30.0  1.99878
# knn      3.0  3.0  164.000000  24.393814       30.0 -1.00000
# knn_rd   3.0  3.0  164.000000  24.725058       30.0  2.00000
# qbc      3.0  3.0  164.000000  18.070204       30.0 -1.00000
# qbc_rd   3.0  3.0  164.000000  18.268180       30.0  2.00000
# kout, kin : 3 4
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       3.0  4.0  163.256881  17.139686       30.0 -1.000000
# gp_rd    3.0  4.0  164.004279  21.560218       30.0  2.005501
# knn      3.0  4.0  164.000000  27.604726       30.0 -1.000000
# knn_rd   3.0  4.0  164.000000  25.949423       30.0  2.000000
# qbc      3.0  4.0  164.000000  19.317394       30.0 -1.000000
# qbc_rd   3.0  4.0  164.000000  18.700927       30.0  2.000000
# kout, kin : 4 0
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       4.0  0.0  164.262195  19.330280       30.0  -1.0
# gp_rd    4.0  0.0  163.878806  24.506658       30.0   2.0
# knn      4.0  0.0  164.000000  32.164022       30.0  -1.0
# knn_rd   4.0  0.0  164.000000  31.174132       30.0   2.0
# qbc      4.0  0.0  164.000000  22.521955       30.0  -1.0
# qbc_rd   4.0  0.0  164.000000  24.805609       30.0   2.0
# kout, kin : 4 1
#         kout  kin         day       rmse  lastKDays     seed
# reg
# gp       4.0  1.0  163.300310  25.085696       30.0 -1.00000
# gp_rd    4.0  1.0  164.159243  31.729449       30.0  2.00061
# knn      4.0  1.0  164.000000  33.708013       30.0 -1.00000
# knn_rd   4.0  1.0  164.000000  31.862370       30.0  2.00000
# qbc      4.0  1.0  164.000000  25.179396       30.0 -1.00000
# qbc_rd   4.0  1.0  164.000000  26.055273       30.0  2.00000
# kout, kin : 4 2
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       4.0  2.0  164.000000  17.861849       30.0 -1.000000
# gp_rd    4.0  2.0  163.862111  23.308360       30.0  2.002441
# knn      4.0  2.0  164.000000  31.817300       30.0 -1.000000
# knn_rd   4.0  2.0  164.000000  31.503080       30.0  2.000000
# qbc      4.0  2.0  164.000000  23.413676       30.0 -1.000000
# qbc_rd   4.0  2.0  164.000000  24.238557       30.0  2.000000
# kout, kin : 4 3
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       4.0  3.0  164.149847  19.528919       30.0 -1.000000
# gp_rd    4.0  3.0  164.092355  29.399513       30.0  2.006116
# knn      4.0  3.0  164.000000  30.263679       30.0 -1.000000
# knn_rd   4.0  3.0  164.000000  30.592756       30.0  2.000000
# qbc      4.0  3.0  164.000000  24.581745       30.0 -1.000000
# qbc_rd   4.0  3.0  164.000000  25.473633       30.0  2.000000
# kout, kin : 4 4
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       4.0  4.0  164.000000  17.144697       30.0  -1.0
# gp_rd    4.0  4.0  163.896468  22.093865       30.0   2.0
# knn      4.0  4.0  164.000000  32.270451       30.0  -1.0
# knn_rd   4.0  4.0  164.000000  32.725061       30.0   2.0
# qbc      4.0  4.0  164.000000  22.589314       30.0  -1.0
# qbc_rd   4.0  4.0  164.000000  26.948920       30.0   2.0
# kout, kin : 5 0
#         kout  kin         day       rmse  lastKDays     seed
# reg
# gp       5.0  0.0  164.299694  20.802790       30.0 -1.00000
# gp_rd    5.0  0.0  163.894512  18.467032       30.0  1.99878
# knn      5.0  0.0  164.000000  30.955746       30.0 -1.00000
# knn_rd   5.0  0.0  164.000000  28.135533       30.0  2.00000
# qbc      5.0  0.0  164.000000  21.625199       30.0 -1.00000
# qbc_rd   5.0  0.0  164.000000  21.215199       30.0  2.00000
# kout, kin : 5 1
#         kout  kin         day       rmse  lastKDays  seed
# reg
# gp       5.0  1.0  164.150769  28.539573       30.0  -1.0
# gp_rd    5.0  1.0  164.129799  27.092203       30.0   2.0
# knn      5.0  1.0  164.000000  31.637220       30.0  -1.0
# knn_rd   5.0  1.0  164.000000  29.261099       30.0   2.0
# qbc      5.0  1.0  164.000000  21.547894       30.0  -1.0
# qbc_rd   5.0  1.0  164.000000  24.142987       30.0   2.0
# kout, kin : 5 2
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       5.0  2.0  164.000000  19.864871       30.0 -1.000000
# gp_rd    5.0  2.0  164.063299  19.604080       30.0  1.999391
# knn      5.0  2.0  164.000000  28.790155       30.0 -1.000000
# knn_rd   5.0  2.0  164.000000  27.486032       30.0  2.000000
# qbc      5.0  2.0  164.000000  23.058876       30.0 -1.000000
# qbc_rd   5.0  2.0  164.000000  22.179516       30.0  2.000000
# kout, kin : 5 3
#         kout  kin         day       rmse  lastKDays      seed
# reg
# gp       5.0  3.0  164.311927  22.138171       30.0 -1.000000
# gp_rd    5.0  3.0  164.012852  23.888605       30.0  1.999388
# knn      5.0  3.0  164.000000  27.363850       30.0 -1.000000
# knn_rd   5.0  3.0  164.000000  26.582794       30.0  2.000000
# qbc      5.0  3.0  164.000000  22.283299       30.0 -1.000000
# qbc_rd   5.0  3.0  164.000000  20.713087       30.0  2.000000
# kout, kin : 5 4
#         kout  kin         day       rmse  lastKDays     seed
# reg
# gp       5.0  4.0  164.256098  22.014978       30.0 -1.00000
# gp_rd    5.0  4.0  163.889634  21.579490       30.0  1.99939
# knn      5.0  4.0  164.000000  31.496932       30.0 -1.00000
# knn_rd   5.0  4.0  164.000000  28.812799       30.0  2.00000
# qbc      5.0  4.0  164.000000  24.472149       30.0 -1.00000
# qbc_rd   5.0  4.0  164.000000  23.264521       30.0  2.00000

# %%
for reg in ['gp', 'qbc']: # (3, 0), (1,0), (1,1), (2,0), (2, 1), (5,0)
    for kout, kin in [ (2, 4), (1,1)]:
        print (kout, kin, "beneath")
        sts_ftrain_index, sts_test_index = list(kfout.split(allStations))[kout]
        sts_train_index, sts_val_index = list(kfin.split(sts_ftrain_index))[kin]

        # get the station ids
        sts_test = list(allStations[sts_test_index]) # test
        sts_val = list(allStations[sts_ftrain_index[sts_val_index]]) # train
        sts_pool = list(allStations[sts_ftrain_index[sts_train_index]]) # pool
        sts_train = [] # pool

        grouped = datadf.groupby("station_id")

        queried_stations = np.load(f"../exp2/src/{results}/{lastKDays}/final_{reg}/{kout}_{kin}/stations.npy")
        for qix, qStation in enumerate(queried_stations):
            # get the index of the stations
            sts_pool.remove(qStation)
            sts_train = [qStation]
            
            
            for ix, (marker, strStations, stations) in enumerate(zip(
                ["*", 'o', 'o'],
                ["Test Stations", "Train Stations", "Unmonitored Locations"], 
                [sts_test, sts_val, sts_train+ sts_pool]
            )):

                longs = []
                lats = []
                for station in stations:
                    tempdf = grouped.get_group(station)
                    long = tempdf["longitude"].mean()
                    lat = tempdf["latitude"].mean()

        #             print ("done")
        #             print (long)
        #             assert (len(long) == 1)
        #             assert (len(lat) == 1)

                    longs.append(long)
                    lats.append(lat)

                if ix == 2:
                    linestyle = '--'
                    alpha = .3
                    temp = 3
                else:
                    alpha = .8
                    linestyle = '-'
                    temp = ix
                if qix in [len(queried_stations)-1, 0]:
                    plt.scatter(longs, lats, 
                                label=strStations, 
                                c=tableau20blind[temp * 2],
                                s=300,
                                marker=marker,
                                linestyle = linestyle, 
                                alpha = alpha,
                               )
            if qix in [len(queried_stations)-1, 0]:
                plt.legend(loc="upper")
                plt.xlabel("Longitude (Scaled)")
                plt.ylabel("Latitude (Scaled)")
#                 plt.title(f"{reg}")
                format_axes(plt.gca())
                if qix == 0:
                    qqix = "start"
                else:
                    qqix = "last"
                plt.savefig(f'./plts/{reg}_kout{kout}_kin{kin}_{qqix}.pdf')
                plt.show()
            sts_val.append(qStation)
# Out:
# 2 4 beneath
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /home/apoorv/Desktop/github/.env/lib/python3.6/site-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Unrecognized location 'upper'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# /home/apoorv/Desktop/github/.env/lib/python3.6/site-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Unrecognized location 'upper'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 1 1 beneath
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2 4 beneath
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 1 1 beneath
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
